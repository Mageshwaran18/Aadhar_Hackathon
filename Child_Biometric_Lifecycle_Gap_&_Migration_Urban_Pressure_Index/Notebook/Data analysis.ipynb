# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
demographic_data = pd.read_csv('..\\Data\\normalized_demographic\\normalized_demographic.csv')

# %%
demographic_data.shape
# Out:
# (2045700, 6)

# %%
demographic_data.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   uttar_pradesh   gorakhpur   273213             49
# 1  01-03-2025  andhra_pradesh    chittoor   517132             22
# 2  01-03-2025         gujarat      rajkot   360006             65
# 3  01-03-2025  andhra_pradesh  srikakulam   532484             24
# 4  01-03-2025       rajasthan     udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
demographic_data["state"].value_counts()
# Out:
# state
# tamil_nadu                                  196857
# west_bengal                                 169070
# uttar_pradesh                               167889
# maharashtra                                 162242
# karnataka                                   152473
# andhra_pradesh                              148746
# telangana                                   130355
# odisha                                      105935
# kerala                                      105515
# bihar                                        97621
# gujarat                                      96399
# rajasthan                                    89508
# madhya_pradesh                               76364
# assam                                        55682
# punjab                                       49611
# jharkhand                                    39653
# chhattisgarh                                 35730
# haryana                                      28554
# ...

# %%
biometric_data = pd.read_csv('..\\Data\\normalized_biometric1\\normalized_biometric1.csv')

# %%
biometric_data.shape
# Out:
# (1861108, 6)

# %%
biometric_data["state"].value_counts()
# Out:
# state
# tamil nadu                                  184582
# uttar pradesh                               155242
# maharashtra                                 151104
# karnataka                                   141227
# andhra pradesh                              132390
# west bengal                                 130895
# telangana                                   122254
# odisha                                       99674
# kerala                                       98511
# gujarat                                      89531
# bihar                                        83398
# rajasthan                                    79724
# madhya pradesh                               70080
# punjab                                       48126
# assam                                        47643
# jharkhand                                    36625
# chhattisgarh                                 31997
# himachal pradesh                             30385
# ...

# %%
biometric_data.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            haryana  mahendragarh   123029           280
# 1  01-03-2025              bihar     madhepura   852121           144
# 2  01-03-2025  jammu and kashmir        poonch   185101           643
# 3  01-03-2025              bihar       bhojpur   802158           256
# 4  01-03-2025         tamil nadu       madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
enrollment_data = pd.read_csv('..\\Data\\normalized_enrollment\\normalized_enrollment.csv')

# %%
enrollment_data.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      meghalaya  east khasi hills   793121       11        61
# 1  09-03-2025      karnataka   bengaluru urban   560043       14        33
# 2  09-03-2025  uttar pradesh      kanpur nagar   208001       29        82
# 3  09-03-2025  uttar pradesh           aligarh   202133       62        29
# 4  09-03-2025      karnataka   bengaluru urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
print(enrollment_data["date"].max())
print(enrollment_data["date"].min())
# Out:
# 31-12-2025
# 01-04-2025

# %%
print(biometric_data["date"].max())
print(biometric_data["date"].min())
# Out:
# 31-10-2025
# 01-03-2025

# %%
enrollment_data.groupby(['state', 'district']).size().sort_values(ascending=False).head()
biometric_data.groupby(['state', 'district']).size().sort_values(ascending=False).head()
# Out:
# state           district
# andhra pradesh  ananthapuramu        18372
# karnataka       bengaluru urban      16803
# west bengal     purba bardhaman      16652
# karnataka       belagavi             14424
# west bengal     north 24 parganas    13435
# dtype: int64

# %%
enrollment_data.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
biometric_data.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
demographic_data.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
#       dtype='object')
